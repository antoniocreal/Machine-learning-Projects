# %% [markdown]
# # Tensorboard
#
# ---
# ---
#
# **NOTE: You must watch the corresponding video to understand this lecture. This notebook can't serve as a full guide. Please watch the video BEFORE posting questions to the QA forum.**
#
# ---
# ---
#
# Let's explore the built in data visualization capabilities that come with Tensorboard.
#
# Full official tutorial available here: https://www.tensorflow.org/tensorboard/get_started
#
# ## Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# might be needed depending on your version of Jupyter
# %matplotlib inline

# %%
df = pd.read_csv('/home/acr/Documents/Course: Python for Data Science and Machine Learning Bootcamp/TensorFlow_FILES/DATA/cancer_classification.csv')
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  \
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
#      benign_0__mal_1
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 564                0
# 565                0
# 566                0
# 567                0
# 568                1
#
# [569 rows x 31 columns]

# %% [markdown]
# ### Train Test Split

# %%
X = df.drop('benign_0__mal_1',axis=1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %% [markdown]
# ### Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
# Out:
# 2022-01-07 12:10:57.799816: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-07 12:10:57.799847: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %% [markdown]
# ## Creating the Tensorboard Callback
#
# TensorBoard is a visualization tool provided with TensorFlow.
#
# This callback logs events for TensorBoard, including:
# * Metrics summary plots
# * Training graph visualization
# * Activation histograms
# * Sampled profiling
#
# If you have installed TensorFlow with pip, you should be able
# to launch TensorBoard from the command line:
#
# ```sh
# tensorboard --logdir=path_to_your_logs
# ```
#
# You can find more information about TensorBoard
# [here](https://www.tensorflow.org/tensorboard/).
#
#     Arguments:
#         log_dir: the path of the directory where to save the log files to be
#           parsed by TensorBoard.
#         histogram_freq: frequency (in epochs) at which to compute activation and
#           weight histograms for the layers of the model. If set to 0, histograms
#           won't be computed. Validation data (or split) must be specified for
#           histogram visualizations.
#         write_graph: whether to visualize the graph in TensorBoard. The log file
#           can become quite large when write_graph is set to True.
#         write_images: whether to write model weights to visualize as image in
#           TensorBoard.
#         update_freq: `'batch'` or `'epoch'` or integer. When using `'batch'`,
#           writes the losses and metrics to TensorBoard after each batch. The same
#           applies for `'epoch'`. If using an integer, let's say `1000`, the
#           callback will write the metrics and losses to TensorBoard every 1000
#           samples. Note that writing too frequently to TensorBoard can slow down
#           your training.
#         profile_batch: Profile the batch to sample compute characteristics. By
#           default, it will profile the second batch. Set profile_batch=0 to
#           disable profiling. Must run in TensorFlow eager mode.
#         embeddings_freq: frequency (in epochs) at which embedding layers will
#           be visualized. If set to 0, embeddings won't be visualized.

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2022-01-07--1214'

# %%
pwd
# Out:
# '/home/acr/Documents/Course: Python for Data Science and Machine Learning Bootcamp/Jupyter/Machine Learning/Neural Networks and Deep Learning'

# %%
# WINDOWS: Use "logs\\fit"
# MACOS/LINUX: Use "logs\fit"

log_directory = 'logs\\fit' # Tem de ser este senão não resulta

# OPTIONAL: ADD A TIMESTAMP FOR UNIQUE FOLDER
# timestamp = datetime.now().strftime("%Y-%m-%d--%H%M")
# log_directory = log_directory + '\\' + timestamp


board = TensorBoard(log_dir=log_directory,histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=2,
    embeddings_freq=1)
# Out:
# 2022-01-07 12:28:57.065726: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2022-01-07 12:28:57.065775: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
# 2022-01-07 12:28:57.066724: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.

# %%
model = Sequential()

# %%
model.add(Dense(units=30,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=15,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# ## Train the Model

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop,board]
          )
# Out:
# Epoch 1/600
#  3/14 [=====>........................] - ETA: 0s - loss: 0.7181
# 2022-01-07 12:29:03.214193: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2022-01-07 12:29:03.214240: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
# 2022-01-07 12:29:03.254215: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2022-01-07 12:29:03.255382: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2022-01-07 12:29:03.257484: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs\fit/plugins/profile/2022_01_07_12_29_03
#
# 2022-01-07 12:29:03.258702: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to logs\fit/plugins/profile/2022_01_07_12_29_03/acrps.trace.json.gz
# 2022-01-07 12:29:03.260611: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs\fit/plugins/profile/2022_01_07_12_29_03
#
# 2022-01-07 12:29:03.260715: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to logs\fit/plugins/profile/2022_01_07_12_29_03/acrps.memory_profile.json.gz
# 2022-01-07 12:29:03.261008: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs\fit/plugins/profile/2022_01_07_12_29_03
# Dumped tool data for xplane.pb to logs\fit/plugins/profile/2022_01_07_12_29_03/acrps.xplane.pb
# Dumped tool data for overview_page.pb to logs\fit/plugins/profile/2022_01_07_12_29_03/acrps.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs\fit/plugins/profile/2022_01_07_12_29_03/acrps.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs\fit/plugins/profile/2022_01_07_12_29_03/acrps.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs\fit/plugins/profile/2022_01_07_12_29_03/acrps.kernel_stats.pb
# 14/14 [==============================] - 1s 26ms/step - loss: 0.6957 - val_loss: 0.6732
# Epoch 2/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6748 - val_loss: 0.6519
# Epoch 3/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6477 - val_loss: 0.6283
# Epoch 4/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6388 - val_loss: 0.6018
# Epoch 5/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6265 - val_loss: 0.5748
# Epoch 6/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5899 - val_loss: 0.5414
# Epoch 7/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5514 - val_loss: 0.5029
# Epoch 8/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5452 - val_loss: 0.4760
# Epoch 9/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5246 - val_loss: 0.4516
# Epoch 10/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4796 - val_loss: 0.4243
# Epoch 11/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4745 - val_loss: 0.3965
# Epoch 12/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4441 - val_loss: 0.3689
# Epoch 13/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4321 - val_loss: 0.3447
# Epoch 14/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4418 - val_loss: 0.3271
# Epoch 15/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4043 - val_loss: 0.3047
# Epoch 16/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3904 - val_loss: 0.2847
# Epoch 17/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3821 - val_loss: 0.2736
# Epoch 18/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3835 - val_loss: 0.2634
# Epoch 19/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3277 - val_loss: 0.2429
# Epoch 20/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3222 - val_loss: 0.2211
# Epoch 21/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3260 - val_loss: 0.2097
# Epoch 22/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3274 - val_loss: 0.2016
# Epoch 23/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3208 - val_loss: 0.1988
# Epoch 24/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2994 - val_loss: 0.1899
# Epoch 25/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3145 - val_loss: 0.1880
# Epoch 26/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2846 - val_loss: 0.1851
# Epoch 27/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2687 - val_loss: 0.1796
# Epoch 28/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2606 - val_loss: 0.1685
# Epoch 29/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2396 - val_loss: 0.1634
# Epoch 30/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2573 - val_loss: 0.1604
# Epoch 31/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2336 - val_loss: 0.1491
# Epoch 32/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2330 - val_loss: 0.1435
# Epoch 33/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2370 - val_loss: 0.1443
# Epoch 34/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2381 - val_loss: 0.1447
# Epoch 35/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2232 - val_loss: 0.1444
# Epoch 36/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2114 - val_loss: 0.1331
# Epoch 37/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2264 - val_loss: 0.1310
# Epoch 38/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2246 - val_loss: 0.1328
# Epoch 39/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2051 - val_loss: 0.1318
# Epoch 40/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1826 - val_loss: 0.1242
# Epoch 41/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2088 - val_loss: 0.1303
# Epoch 42/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1874 - val_loss: 0.1272
# Epoch 43/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1830 - val_loss: 0.1198
# Epoch 44/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1781 - val_loss: 0.1264
# Epoch 45/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1684 - val_loss: 0.1170
# Epoch 46/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2195 - val_loss: 0.1155
# Epoch 47/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1802 - val_loss: 0.1113
# Epoch 48/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1827 - val_loss: 0.1152
# Epoch 49/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1837 - val_loss: 0.1135
# Epoch 50/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1463 - val_loss: 0.1160
# Epoch 51/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1671 - val_loss: 0.1132
# Epoch 52/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1624 - val_loss: 0.1095
# Epoch 53/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1486 - val_loss: 0.1107
# Epoch 54/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1466 - val_loss: 0.1148
# Epoch 55/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1480 - val_loss: 0.1046
# Epoch 56/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1562 - val_loss: 0.1071
# Epoch 57/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1373 - val_loss: 0.1115
# Epoch 58/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1429 - val_loss: 0.1078
# Epoch 59/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1458 - val_loss: 0.1165
# Epoch 60/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1335 - val_loss: 0.1089
# Epoch 61/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1640 - val_loss: 0.1036
# Epoch 62/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1556 - val_loss: 0.1049
# Epoch 63/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1564 - val_loss: 0.1018
# Epoch 64/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1401 - val_loss: 0.0997
# Epoch 65/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1374 - val_loss: 0.1106
# Epoch 66/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1229 - val_loss: 0.1049
# Epoch 67/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1125 - val_loss: 0.1001
# Epoch 68/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1376 - val_loss: 0.1019
# Epoch 69/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1462 - val_loss: 0.0972
# Epoch 70/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1391 - val_loss: 0.1058
# Epoch 71/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1231 - val_loss: 0.1117
# Epoch 72/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1250 - val_loss: 0.1132
# Epoch 73/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1220 - val_loss: 0.1016
# Epoch 74/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1356 - val_loss: 0.1072
# Epoch 75/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1504 - val_loss: 0.1087
# Epoch 76/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1457 - val_loss: 0.1025
# Epoch 77/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1112 - val_loss: 0.1082
# Epoch 78/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1210 - val_loss: 0.0968
# Epoch 79/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1182 - val_loss: 0.0985
# Epoch 80/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1287 - val_loss: 0.1003
# Epoch 81/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1127 - val_loss: 0.0990
# Epoch 82/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1077 - val_loss: 0.1055
# Epoch 83/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1200 - val_loss: 0.1103
# Epoch 84/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0952 - val_loss: 0.0969
# Epoch 85/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1052 - val_loss: 0.1013
# Epoch 86/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1053 - val_loss: 0.1225
# Epoch 87/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0967 - val_loss: 0.0993
# Epoch 88/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1070 - val_loss: 0.0969
# Epoch 89/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1199 - val_loss: 0.0995
# Epoch 90/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1136 - val_loss: 0.0982
# Epoch 91/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1133 - val_loss: 0.1015
# Epoch 92/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1068 - val_loss: 0.1019
# Epoch 93/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1221 - val_loss: 0.0938
# Epoch 94/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1058 - val_loss: 0.1013
# Epoch 95/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1258 - val_loss: 0.1006
# Epoch 96/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1128 - val_loss: 0.1030
# Epoch 97/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1101 - val_loss: 0.1041
# Epoch 98/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0993 - val_loss: 0.0975
# Epoch 99/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1052 - val_loss: 0.1031
# Epoch 100/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1104 - val_loss: 0.1208
# Epoch 101/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1011 - val_loss: 0.1024
# Epoch 102/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1443 - val_loss: 0.1054
# Epoch 103/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1008 - val_loss: 0.1091
# Epoch 104/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1196 - val_loss: 0.0972
# Epoch 105/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1167 - val_loss: 0.0997
# Epoch 106/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1160 - val_loss: 0.0968
# Epoch 107/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1082 - val_loss: 0.1167
# Epoch 108/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1025 - val_loss: 0.1116
# Epoch 109/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1115 - val_loss: 0.1021
# Epoch 110/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0990 - val_loss: 0.0991
# Epoch 111/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0932 - val_loss: 0.1151
# Epoch 112/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0913 - val_loss: 0.1005
# Epoch 113/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0943 - val_loss: 0.0934
# Epoch 114/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1111 - val_loss: 0.1039
# Epoch 115/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1060 - val_loss: 0.1010
# Epoch 116/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1054 - val_loss: 0.0997
# Epoch 117/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1029 - val_loss: 0.0960
# Epoch 118/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1124 - val_loss: 0.1055
# Epoch 119/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1015 - val_loss: 0.0968
# Epoch 120/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0801 - val_loss: 0.1029
# Epoch 121/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0919 - val_loss: 0.0988
# Epoch 122/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1068 - val_loss: 0.1005
# Epoch 123/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0956 - val_loss: 0.1134
# Epoch 124/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0949 - val_loss: 0.0986
# Epoch 125/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1061 - val_loss: 0.1096
# Epoch 126/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0970 - val_loss: 0.1036
# Epoch 127/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0922 - val_loss: 0.1032
# Epoch 128/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1108 - val_loss: 0.1087
# Epoch 129/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0923 - val_loss: 0.1051
# Epoch 130/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1053 - val_loss: 0.1201
# Epoch 131/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0769 - val_loss: 0.0964
# Epoch 132/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0953 - val_loss: 0.1118
# Epoch 133/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0990 - val_loss: 0.1062
# Epoch 134/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0860 - val_loss: 0.0968
# Epoch 135/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0890 - val_loss: 0.0978
# Epoch 136/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0794 - val_loss: 0.1049
# Epoch 137/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0906 - val_loss: 0.0972
# Epoch 138/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0998 - val_loss: 0.1177
# Epoch 00138: early stopping

# %% [markdown]
# # Running Tensorboard

# %% [markdown]
# ## Running through the Command Line
#
# **Watch video to see how to run Tensorboard through a command line call.**

# %% [markdown]
# Tensorboard will run locally in your browser at [http://localhost:6006/](http://localhost:6006/)

# %%
print(log_directory)
# Out:
# logs\fit

# %%
pwd
# Out:
# '/home/acr/Documents/Course: Python for Data Science and Machine Learning Bootcamp/Jupyter/Machine Learning/Neural Networks and Deep Learning'

# %% [markdown]
# ### Use cd at your command line to change directory to the file path reported back by pwd or your current .py file location.
# ### Then run this code at your command line or terminal

# %%
tensorboard --logdir logs\\fit
